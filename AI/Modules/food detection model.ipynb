jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0692.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0950.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0090.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0892.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0943.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0182.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0217.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0492.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0324.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0977.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0779.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0637.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0589.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0335.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0851.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0387.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0086.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0254.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0236.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0840.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0296.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0099.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0491.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0071.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0201.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0399.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0394.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0638.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0347.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0426.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0699.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0740.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0472.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0730.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0777.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0894.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0443.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0187.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0916.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0987.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0243.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0378.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0621.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0433.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0559.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0209.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0936.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0925.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0501.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0853.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0676.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0417.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0176.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0496.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0097.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0489.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0049.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0284.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0404.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0600.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0994.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0405.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0805.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0175.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0193.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0942.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0866.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0156.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0845.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0468.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0095.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0644.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0200.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0809.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0446.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0887.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0623.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0800.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0885.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0739.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0583.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0045.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0340.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0972.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0791.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0595.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0495.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0667.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0774.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0281.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0051.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0903.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0556.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0241.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0540.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0212.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0900.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0707.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0372.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0414.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0527.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0969.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0804.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0922.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0337.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0605.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0716.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0577.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0255.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0396.jpg
# /kaggle/input/my-food-100-dataset/food100/french_fries/french_fries_0760.jpg

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import os
import zipfile
import json
import time

print(f"TensorFlow Version: {tf.__version__}")
# Out:
# TensorFlow Version: 2.18.0

# %%
# === CONFIGURATION (Our "Control Panel") ===

# --- 1. Data ---
# Kaggle unzipped our data, so we point DIRECTLY to the unzipped folder
# 🛑 غيّر المسار ده للمسار الصح اللي طلعلك
DATA_DIR = "/kaggle/input/my-food-100-dataset/food100" 

# --- 2. Model ---
MODEL_CHOICE = tf.keras.applications.EfficientNetB0
IMG_SIZE = 224
NUM_CLASSES = 100
SEED = 42

# --- 3. Training ---
BATCH_SIZE = 32
VALIDATION_SPLIT = 0.2
EPOCHS_WARMUP = 10
EPOCHS_FINE_TUNE = 30
LR_WARMUP = 0.001
LR_FINE_TUNE = 0.00001

# %%
# --- Cell 5: Step 2: Load & Prepare Datasets ---

print("\n--- Step 2: Loading & Splitting Data ---")

# We load directly from the DATA_DIR in /kaggle/input
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,  # This points to the unzipped folder
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,  # This points to the unzipped folder
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=SEED,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

# --- This is the important part you missed ---
# Save the class names (extremely useful for your final app)
class_names = train_ds.class_names
print(f"\nFound {len(class_names)} classes.")

# Save class names to a JSON file in the output directory
class_names_path = "/kaggle/working/class_names.json"
with open(class_names_path, 'w') as f:
    json.dump(class_names, f)

print(f"Class names saved to {class_names_path}")
# Out:
# --- Step 2: Loading & Splitting Data ---
# Found 98340 files belonging to 100 classes.
# Using 78672 files for training.
# Found 98340 files belonging to 100 classes.
# Using 19668 files for validation.
#
# Found 100 classes.
# Class names saved to /kaggle/working/class_names.json

# %%
print("\n--- Step 3: Defining 'Online' Augmentation Layer ---")

# We build augmentation as a Keras layer.
# This means it runs on the GPU (fast) and is *part* of the saved model.
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal", seed=SEED),
    layers.RandomRotation(0.2, seed=SEED),
    layers.RandomZoom(0.2, seed=SEED),
    layers.RandomContrast(0.2, seed=SEED) # Added for more robustness
], name="data_augmentation")

# Note: EfficientNet *expects* pixel values in the [0, 255] range.
# We do NOT need a Rescaling(1./255) layer or the preprocess_input function.
# Out:
# --- Step 3: Defining 'Online' Augmentation Layer ---

# %%
# --- Cell 7: Step 4: Configure Dataset for Performance ---

print("\n--- Step 4: Configuring Dataset for Performance ---")

# We REMOVED .cache() to prevent Out-of-Memory errors.
# We KEEP .prefetch() because it's crucial for performance.
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE) # <--- شيلنا .cache()
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE) # <--- شيلنا .cache()

print("Dataset performance pipeline configured (without cache).")
# Out:
# --- Step 4: Configuring Dataset for Performance ---
# Dataset performance pipeline configured (without cache).

# %%
print("\n--- Step 5: Building Model (Phase 1 - Warmup) ---")

# 1. Load the pre-trained base model
base_model = MODEL_CHOICE(
    include_top=False,
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# 2. Freeze the base (this is the key to "warmup")
base_model.trainable = False

# 3. Build our full model
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="input_layer")
# Apply augmentation "online"
x = data_augmentation(inputs)
# Pass to the frozen base
x = base_model(x, training=False) 
# Build our new "head"
x = layers.GlobalAveragePooling2D(name="pooling_layer")(x)
x = layers.Dropout(0.3, name="dropout_layer")(x) # Regularization
outputs = layers.Dense(NUM_CLASSES, activation="softmax", name="output_layer")(x)
model = keras.Model(inputs, outputs)

# 4. Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LR_WARMUP),
    loss="sparse_categorical_crossentropy", # Use sparse (integer labels)
    metrics=["accuracy"]
)

print("Model built and compiled for warmup.")
model.summary()
# Out:
# --- Step 5: Building Model (Phase 1 - Warmup) ---
# Model built and compiled for warmup.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pooling_layer                   │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer (Dropout)         │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 100)            │       128,100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,177,671 (15.94 MB)
#  Trainable params: 128,100 (500.39 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
print("\n--- Step 6: Defining Callbacks ---")

# Callbacks are our "safety net" for long training jobs.

# 1. ModelCheckpoint: Saves the *best* model file.
checkpoint_path = "/kaggle/working/best_model_food100.keras"
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    save_best_only=True, # This is the key!
    monitor="val_accuracy",
    mode="max",
    verbose=1
)

# 2. EarlyStopping: Stops training if it doesn't improve.
# This saves your GPU quota!
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5, # Wait 5 epochs with no improvement
    restore_best_weights=True, # Automatically load the best weights back
    verbose=1
)

# 3. ReduceLROnPlateau: Lowers the learning rate if we get stuck.
reduce_lr_cb = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.2, # Reduce LR by 80% (new_lr = lr * 0.2)
    patience=2,
    verbose=1
)
# Out:
# --- Step 6: Defining Callbacks ---

# %%
print("\n--- Step 7: Starting Training (Phase 1: Warmup) ---")

# We train only the new head
history_warmup = model.fit(
    train_ds,
    epochs=EPOCHS_WARMUP,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, early_stopping_cb, reduce_lr_cb]
)

print("Warmup complete.")
# Out:
# --- Step 7: Starting Training (Phase 1: Warmup) ---
# Epoch 1/10
# E0000 00:00:1761406723.712112     449 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_3_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4753 - loss: 2.2703
# Epoch 1: val_accuracy improved from -inf to 0.73109, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 232s 88ms/step - accuracy: 0.4754 - loss: 2.2698 - val_accuracy: 0.7311 - val_loss: 0.9898 - learning_rate: 0.0010
# Epoch 2/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6796 - loss: 1.2014
# Epoch 2: val_accuracy improved from 0.73109 to 0.76083, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 214s 87ms/step - accuracy: 0.6796 - loss: 1.2014 - val_accuracy: 0.7608 - val_loss: 0.8651 - learning_rate: 0.0010
# Epoch 3/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7028 - loss: 1.0974
# Epoch 3: val_accuracy improved from 0.76083 to 0.77135, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 215s 87ms/step - accuracy: 0.7028 - loss: 1.0974 - val_accuracy: 0.7714 - val_loss: 0.8239 - learning_rate: 0.0010
# Epoch 4/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7122 - loss: 1.0425
# Epoch 4: val_accuracy improved from 0.77135 to 0.78132, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 215s 87ms/step - accuracy: 0.7122 - loss: 1.0425 - val_accuracy: 0.7813 - val_loss: 0.7889 - learning_rate: 0.0010
# Epoch 5/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7217 - loss: 1.0167
# Epoch 5: val_accuracy did not improve from 0.78132
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 214s 87ms/step - accuracy: 0.7217 - loss: 1.0167 - val_accuracy: 0.7805 - val_loss: 0.7855 - learning_rate: 0.0010
# Epoch 6/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7255 - loss: 0.9968
# Epoch 6: val_accuracy improved from 0.78132 to 0.78823, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 215s 87ms/step - accuracy: 0.7255 - loss: 0.9968 - val_accuracy: 0.7882 - val_loss: 0.7623 - learning_rate: 0.0010
# Epoch 7/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7280 - loss: 0.9848
# Epoch 7: val_accuracy improved from 0.78823 to 0.79118, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 216s 88ms/step - accuracy: 0.7280 - loss: 0.9848 - val_accuracy: 0.7912 - val_loss: 0.7527 - learning_rate: 0.0010
# Epoch 8/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7303 - loss: 0.9781
# Epoch 8: val_accuracy did not improve from 0.79118
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 215s 87ms/step - accuracy: 0.7303 - loss: 0.9781 - val_accuracy: 0.7906 - val_loss: 0.7548 - learning_rate: 0.0010
# Epoch 9/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7306 - loss: 0.9715
# Epoch 9: val_accuracy improved from 0.79118 to 0.79301, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 214s 87ms/step - accuracy: 0.7306 - loss: 0.9715 - val_accuracy: 0.7930 - val_loss: 0.7434 - learning_rate: 0.0010
# Epoch 10/10
# 2458/2459 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7324 - loss: 0.9606
# Epoch 10: val_accuracy improved from 0.79301 to 0.79337, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 ━━━━━━━━━━━━━━━━━━━━ 215s 87ms/step - accuracy: 0.7324 - loss: 0.9606 - val_accuracy: 0.7934 - val_loss: 0.7427 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Warmup complete.

# %%
print("\n--- Step 8: Unfreezing for Fine-Tuning ---")

# 1. Unfreeze the base model
base_model.trainable = True

# 2. Re-compile with a *tiny* learning rate
# This is CRITICAL to prevent destroying the learned weights.
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LR_FINE_TUNE), # 1e-5
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Model un-frozen and re-compiled for fine-tuning.")
model.summary()
# Out:
# --- Step 8: Unfreezing for Fine-Tuning ---
# Model un-frozen and re-compiled for fine-tuning.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pooling_layer                   │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer (Dropout)         │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 100)            │       128,100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,177,671 (15.94 MB)
#  Trainable params: 4,135,648 (15.78 MB)
#  Non-trainable params: 42,023 (164.16 KB)

# %%
print("\n--- Step 9: Starting Training (Phase 2: Fine-Tuning) ---")

# Continue training the *entire* model
# We set 'initial_epoch' so the epoch counter and history plots continue smoothly
total_epochs = EPOCHS_WARMUP + EPOCHS_FINE_TUNE

history_fine_tune = model.fit(
    train_ds,
    epochs=total_epochs,
    initial_epoch=history_warmup.epoch[-1] + 1, # Start from where we left off
    validation_data=val_ds,
    callbacks=[checkpoint_cb, early_stopping_cb, reduce_lr_cb],
    verbose=2  # <--- ده هو التعديل اللي هيمنع التهنيج
)

print("Fine-tuning complete.")
# Out:
# --- Step 9: Starting Training (Phase 2: Fine-Tuning) ---
# Epoch 11/40
# E0000 00:00:1761409255.539075     449 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_3_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# Epoch 11: val_accuracy did not improve from 0.79337
# 2459/2459 - 884s - 360ms/step - accuracy: 0.5298 - loss: 1.8529 - val_accuracy: 0.6949 - val_loss: 1.1390 - learning_rate: 1.0000e-05
# Epoch 12/40
#
# Epoch 12: val_accuracy did not improve from 0.79337
# 2459/2459 - 826s - 336ms/step - accuracy: 0.6864 - loss: 1.1391 - val_accuracy: 0.7546 - val_loss: 0.9065 - learning_rate: 1.0000e-05
# Epoch 13/40
#
# Epoch 13: val_accuracy did not improve from 0.79337
# 2459/2459 - 828s - 337ms/step - accuracy: 0.7367 - loss: 0.9366 - val_accuracy: 0.7875 - val_loss: 0.7840 - learning_rate: 1.0000e-05
# Epoch 14/40
#
# Epoch 14: val_accuracy improved from 0.79337 to 0.80440, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 828s - 337ms/step - accuracy: 0.7644 - loss: 0.8316 - val_accuracy: 0.8044 - val_loss: 0.7216 - learning_rate: 1.0000e-05
# Epoch 15/40
#
# Epoch 15: val_accuracy improved from 0.80440 to 0.81533, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 336ms/step - accuracy: 0.7855 - loss: 0.7570 - val_accuracy: 0.8153 - val_loss: 0.6766 - learning_rate: 1.0000e-05
# Epoch 16/40
#
# Epoch 16: val_accuracy improved from 0.81533 to 0.82505, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 828s - 337ms/step - accuracy: 0.8001 - loss: 0.7011 - val_accuracy: 0.8250 - val_loss: 0.6383 - learning_rate: 1.0000e-05
# Epoch 17/40
#
# Epoch 17: val_accuracy improved from 0.82505 to 0.83272, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 829s - 337ms/step - accuracy: 0.8123 - loss: 0.6577 - val_accuracy: 0.8327 - val_loss: 0.6082 - learning_rate: 1.0000e-05
# Epoch 18/40
#
# Epoch 18: val_accuracy improved from 0.83272 to 0.83882, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 830s - 337ms/step - accuracy: 0.8229 - loss: 0.6210 - val_accuracy: 0.8388 - val_loss: 0.5876 - learning_rate: 1.0000e-05
# Epoch 19/40
#
# Epoch 19: val_accuracy improved from 0.83882 to 0.84386, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 336ms/step - accuracy: 0.8308 - loss: 0.5923 - val_accuracy: 0.8439 - val_loss: 0.5671 - learning_rate: 1.0000e-05
# Epoch 20/40
#
# Epoch 20: val_accuracy improved from 0.84386 to 0.84833, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 828s - 337ms/step - accuracy: 0.8366 - loss: 0.5664 - val_accuracy: 0.8483 - val_loss: 0.5527 - learning_rate: 1.0000e-05
# Epoch 21/40
#
# Epoch 21: val_accuracy improved from 0.84833 to 0.85352, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 828s - 337ms/step - accuracy: 0.8439 - loss: 0.5395 - val_accuracy: 0.8535 - val_loss: 0.5315 - learning_rate: 1.0000e-05
# Epoch 22/40
#
# Epoch 22: val_accuracy improved from 0.85352 to 0.85764, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 830s - 338ms/step - accuracy: 0.8497 - loss: 0.5182 - val_accuracy: 0.8576 - val_loss: 0.5178 - learning_rate: 1.0000e-05
# Epoch 23/40
#
# Epoch 23: val_accuracy improved from 0.85764 to 0.85931, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 828s - 337ms/step - accuracy: 0.8554 - loss: 0.4963 - val_accuracy: 0.8593 - val_loss: 0.5118 - learning_rate: 1.0000e-05
# Epoch 24/40
#
# Epoch 24: val_accuracy improved from 0.85931 to 0.86079, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 337ms/step - accuracy: 0.8606 - loss: 0.4803 - val_accuracy: 0.8608 - val_loss: 0.5054 - learning_rate: 1.0000e-05
# Epoch 25/40
#
# Epoch 25: val_accuracy improved from 0.86079 to 0.86567, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 826s - 336ms/step - accuracy: 0.8644 - loss: 0.4650 - val_accuracy: 0.8657 - val_loss: 0.4901 - learning_rate: 1.0000e-05
# Epoch 26/40
#
# Epoch 26: val_accuracy improved from 0.86567 to 0.86714, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 829s - 337ms/step - accuracy: 0.8695 - loss: 0.4512 - val_accuracy: 0.8671 - val_loss: 0.4835 - learning_rate: 1.0000e-05
# Epoch 27/40
#
# Epoch 27: val_accuracy improved from 0.86714 to 0.86984, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 829s - 337ms/step - accuracy: 0.8732 - loss: 0.4341 - val_accuracy: 0.8698 - val_loss: 0.4755 - learning_rate: 1.0000e-05
# Epoch 28/40
#
# Epoch 28: val_accuracy improved from 0.86984 to 0.87030, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 826s - 336ms/step - accuracy: 0.8763 - loss: 0.4224 - val_accuracy: 0.8703 - val_loss: 0.4713 - learning_rate: 1.0000e-05
# Epoch 29/40
#
# Epoch 29: val_accuracy improved from 0.87030 to 0.87248, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 336ms/step - accuracy: 0.8814 - loss: 0.4064 - val_accuracy: 0.8725 - val_loss: 0.4638 - learning_rate: 1.0000e-05
# Epoch 30/40
#
# Epoch 30: val_accuracy improved from 0.87248 to 0.87513, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 828s - 337ms/step - accuracy: 0.8849 - loss: 0.3971 - val_accuracy: 0.8751 - val_loss: 0.4564 - learning_rate: 1.0000e-05
# Epoch 31/40
#
# Epoch 31: val_accuracy improved from 0.87513 to 0.87797, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 830s - 338ms/step - accuracy: 0.8877 - loss: 0.3871 - val_accuracy: 0.8780 - val_loss: 0.4502 - learning_rate: 1.0000e-05
# Epoch 32/40
#
# Epoch 32: val_accuracy improved from 0.87797 to 0.87864, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 824s - 335ms/step - accuracy: 0.8898 - loss: 0.3750 - val_accuracy: 0.8786 - val_loss: 0.4465 - learning_rate: 1.0000e-05
# Epoch 33/40
#
# Epoch 33: val_accuracy improved from 0.87864 to 0.87925, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 336ms/step - accuracy: 0.8935 - loss: 0.3621 - val_accuracy: 0.8792 - val_loss: 0.4434 - learning_rate: 1.0000e-05
# Epoch 34/40
#
# Epoch 34: val_accuracy improved from 0.87925 to 0.88087, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 336ms/step - accuracy: 0.8955 - loss: 0.3553 - val_accuracy: 0.8809 - val_loss: 0.4355 - learning_rate: 1.0000e-05
# Epoch 35/40
#
# Epoch 35: val_accuracy improved from 0.88087 to 0.88097, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 830s - 338ms/step - accuracy: 0.8995 - loss: 0.3431 - val_accuracy: 0.8810 - val_loss: 0.4383 - learning_rate: 1.0000e-05
# Epoch 36/40
#
# Epoch 36: val_accuracy improved from 0.88097 to 0.88387, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 336ms/step - accuracy: 0.9012 - loss: 0.3372 - val_accuracy: 0.8839 - val_loss: 0.4295 - learning_rate: 1.0000e-05
# Epoch 37/40
#
# Epoch 37: val_accuracy improved from 0.88387 to 0.88479, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 827s - 336ms/step - accuracy: 0.9024 - loss: 0.3295 - val_accuracy: 0.8848 - val_loss: 0.4263 - learning_rate: 1.0000e-05
# Epoch 38/40
#
# Epoch 38: val_accuracy improved from 0.88479 to 0.88591, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 828s - 337ms/step - accuracy: 0.9053 - loss: 0.3209 - val_accuracy: 0.8859 - val_loss: 0.4238 - learning_rate: 1.0000e-05
# Epoch 39/40
#
# Epoch 39: val_accuracy improved from 0.88591 to 0.88626, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 830s - 338ms/step - accuracy: 0.9070 - loss: 0.3150 - val_accuracy: 0.8863 - val_loss: 0.4205 - learning_rate: 1.0000e-05
# Epoch 40/40
#
# Epoch 40: val_accuracy improved from 0.88626 to 0.89028, saving model to /kaggle/working/best_model_food100.keras
# 2459/2459 - 830s - 338ms/step - accuracy: 0.9095 - loss: 0.3049 - val_accuracy: 0.8903 - val_loss: 0.4133 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 40.
# Fine-tuning complete.

# %%
print("\n--- Step 10: Evaluating & Visualizing Results ---")

# 1. Load the *best* model saved by ModelCheckpoint
# This ensures we evaluate the best version, not just the last one.
print("Loading best saved model for final evaluation...")
# We must pass our augmentation layer as a custom object
best_model = tf.keras.models.load_model(
    checkpoint_path
)

# 2. Evaluate on the validation set
loss, acc = best_model.evaluate(val_ds)
print(f"\nFinal Model Accuracy on Validation Set: {acc*100:.2f}%")

# 3. Combine history objects for a complete plot
def plot_history(history_warmup, history_fine_tune):
    acc = history_warmup.history['accuracy'] + history_fine_tune.history['accuracy']
    val_acc = history_warmup.history['val_accuracy'] + history_fine_tune.history['val_accuracy']
    loss = history_warmup.history['loss'] + history_fine_tune.history['loss']
    val_loss = history_warmup.history['val_loss'] + history_fine_tune.history['val_loss']
    
    plt.figure(figsize=(12, 5))
    
    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.axvline(len(history_warmup.history['accuracy']) - 1, color='red', linestyle='--', label='Start Fine-Tuning')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='lower right')
    
    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.axvline(len(history_warmup.history['loss']) - 1, color='red', linestyle='--', label='Start Fine-Tuning')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')
    
    plt.show()

plot_history(history_warmup, history_fine_tune)
# Out:
# --- Step 10: Evaluating & Visualizing Results ---
# Loading best saved model for final evaluation...
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 48s 67ms/step - accuracy: 0.8896 - loss: 0.4195
#
# Final Model Accuracy on Validation Set: 89.03%
